# %%
# Step 0: Install and load Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import warnings
# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
# Step 1: Load the dataset and Explore the data
# 1. Load the mtcars.csv dataset into a dataframe df
df = pd.read_csv('mtcars.csv')
df=df[['car_model'   ,'mpg', 'hp']]

# 2. Study the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   car_model  32 non-null     object
#  1   mpg        32 non-null     float64
#  2   hp         32 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 900.0+ bytes

# %%
df.head(20)
# Out:
#               car_model   mpg   hp
# 0             Mazda RX4  21.0  110
# 1         Mazda RX4 Wag  21.0  110
# 2            Datsun 710  22.8   93
# 3        Hornet 4 Drive  21.4  110
# 4     Hornet Sportabout  18.7  175
# 5               Valiant  18.1  105
# 6            Duster 360  14.3  245
# 7             Merc 240D  24.4   62
# 8              Merc 230  22.8   95
# 9              Merc 280  19.2  123
# 10            Merc 280C  17.8  123
# 11           Merc 450SE  16.4  180
# 12           Merc 450SL  17.3  180
# 13          Merc 450SLC  15.2  180
# 14   Cadillac Fleetwood  10.4  205
# 15  Lincoln Continental  10.4  215
# 16    Chrysler Imperial  14.7  230
# 17             Fiat 128  32.4   66
# 18          Honda Civic  30.4   52
# 19       Toyota Corolla  33.9   65

# %%
# 3. Create a new dataframe called cars to hold numeric data only
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   hp      32 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 640.0 bytes
# None

# %%
# Step 2: Use k-means algorithm to find clusters in the data
# 1. Normalize the cars dataset
# Out:
#         mpg        hp
# 0  0.153299 -0.543655
# 1  0.153299 -0.543655
# 2  0.456737 -0.795570
# 3  0.220730 -0.543655
# 4 -0.234427  0.419550
# 5 -0.335572 -0.617748
# 6 -0.976163  1.456847
# 7  0.726459 -1.254944
# 8  0.456737 -0.765933
# 9 -0.150138 -0.351014

# %%
# 2. Run k-means for k=3, k=10, and k=20
np.random.seed(42)
km3 = KMeans(n_clusters=3).fit(cars_normalized)
km10 = KMeans(n_clusters=10).fit(cars_normalized)
km20 = KMeans(n_clusters=20).fit(cars_normalized)

# %%
# Print predictions and cluster centers
# Out:
# Model with k=3:
# Predictions: [2 2 2 2 2 2 1 0 2 2 2 2 2 1 1 1 1 0 0 0 2 2 2 1 2 0 0 0 1 2 1 2]
# Cluster Centers: [[ 1.54525829 -1.0834728 ]
#  [-1.08784438  1.38090189]
#  [-0.12435606 -0.20370033]]
# Model with k=10:
# Predictions: [1 1 1 1 2 5 0 8 1 5 5 2 2 4 7 7 0 3 3 3 1 4 4 0 2 8 8 9 0 2 6 1]
# Cluster Centers: [[-0.93823285  1.47166539]
#  [ 0.27130259 -0.64103379]
#  [-0.30860011  0.44918673]
#  [ 2.04697368 -1.2697629 ]
#  [-0.80758617  0.1972717 ]
#  [-0.29061864 -0.43992515]
#  [-0.85815908  2.79051468]
#  [-1.63361037  0.93819827]
#  [ 0.97932334 -1.09194053]
#  [ 1.737917   -0.49919927]]
# Model with k=20:
# Predictions: [ 9  9 13  9 10  2  6  3 13 16 16  0  0 17  5  5 18 19 14  7  9 11 11  6
#  10  8 15  1 12 10  4  9]
# Cluster Centers: [[-0.54629279  0.49364233]
#  [ 1.737917   -0.49919927]
#  [-0.33557233 -0.61774753]
#  [ 0.72645879 -1.25494437]
#  [-0.85815908  2.79051468]
#  [-1.63361037  0.93819827]
#  [-1.06045072  1.45684686]
#  [ 2.32793429 -1.21048878]
#  [ 1.21533026 -1.19567025]
#  [ 0.19712899 -0.58514676]
#  [-0.15013833  0.41954967]
#  [-0.79915735  0.04908639]
#  [-0.72329798  1.73839896]
#  [ 0.4567366  -0.78075137]
#  [ 1.737917   -1.40312969]
#  [ 0.99618098 -0.82520696]
#  [-0.26814179 -0.35101396]
#  [-0.8244438   0.49364233]
#  [-0.90873199  1.23456889]
#  [ 2.07506974 -1.19567025]]

# %%
# 3. Visualize clusters based on mpg and hp

# %% [markdown]
# ## Repeat step 1 to 3 but with all the features in the cars dataset and use the resulting clusters for the following steps.

# %%
# Step 1: Load the dataset and Explore the data
# 1. Load the mtcars.csv dataset into a dataframe df
df=[]
df = pd.read_csv('mtcars.csv')


# 3. Create a new dataframe called cars to hold numeric data only


# Step 2: Use k-means algorithm to find clusters in the data
# 1. Normalize the cars dataset


# 2. Run k-means for k=3, k=10, and k=20

# 3. Visualize clusters based on mpg and hp

# %%
# Step 3: Finding the optimal k for k-means
# Perform a grid search

# %%
# Model score for the optimal k
# Out:
# Model score for the optimal k: 132.54135052123922

# %%
# Step 4: Dimensionality Reduction – Principal Component Analysis
# Derive the minimum number of dimensions required to preserve 95% of the dataset variance

# %%
# Print results
print("Dimension d for 95% variance preservation:", d)
print("Significance of dimensionality reduction:", (11 - d) / 11 * 100, "% reduction in dimensions")
# Out:
# Dimension d for 95% variance preservation: 6
# Significance of dimensionality reduction: 45.45454545454545 % reduction in dimensions

# %%
# Derive the X_reduced dataframe
# Out:
# X_reduced dataframe:
#            0         1         2         3         4         5
# 0   0.657213  1.735446 -0.601199  0.115522 -0.960653 -0.017259
# 1   0.629396  1.550033 -0.382322  0.202307 -1.032949 -0.245592
# 2   2.779397 -0.146457 -0.241238 -0.249139  0.405143 -0.354348
# 3   0.311771 -2.363019 -0.135759 -0.511862  0.557997  0.019606
# 4  -1.974489 -0.754402 -1.134402  0.075653  0.210836  0.151580
# 5   0.056138 -2.786000  0.163826 -0.990771  0.215052 -0.247737
# 6  -3.002674  0.334887 -0.362759 -0.052354  0.349350  0.724096
# 7   2.055329 -1.465181  0.943895 -0.144403 -0.321718 -0.001005
# 8   2.287408 -1.983526  1.797241  0.291807 -0.339022 -0.339213
# 9   0.526381 -0.162013  1.492770  0.067324 -0.070738  0.829596
# 10  0.509205 -0.323894  1.683585  0.095867 -0.151185  0.742533
# 11 -2.247810 -0.683474 -0.375383 -0.131875 -0.384669  0.133809
# 12 -2.047823 -0.683221 -0.484464 -0.214367 -0.361302  0.243867
# 13 -2.148542 -0.801739 -0.295110 -0.178138 -0.439055  0.183083
# 14 -3.899790 -0.827948  0.647291  0.295154 -0.049017 -0.898626
# 15 -3.954123 -0.733381  0.720610  0.411823  0.003962 -0.876389
# 16 -3.592972 -0.421135  0.548891  0.676317  0.211356 -0.664104
# 17  3.856284 -0.296752 -0.422827  0.056074  0.223501 -0.475061
# 18  4.254033  0.688414 -0.206841  1.186208  0.099237  0.526345
# 19  4.234221 -0.279287 -0.466255  0.186246  0.225707 -0.322227
# 20  1.904168 -2.119838  0.156796  0.051322  0.039928  0.735279
# 21 -2.184851 -1.014217 -1.168771 -0.594343 -0.229858  0.107918
# 22 -1.863383 -0.906465 -0.962445  0.005785 -0.256607  0.293431
# 23 -2.888995  0.680826 -0.163128  0.827370  0.395345  0.962031
# 24 -2.245919 -0.873812 -1.044406  0.148763  0.304050 -0.201505
# 25  3.573968 -0.121204 -0.453616 -0.013642  0.210062 -0.147311
# 26  2.651255  2.046371 -0.830329  0.577662 -0.606871 -0.344858
# 27  3.385706  1.378599 -0.453865 -1.171650  0.705783  0.016768
# 28 -1.372957  3.500000 -0.136545  0.599541  1.119276 -0.177410
# 29  0.000990  3.219072  0.402094 -0.953957 -0.862416 -0.009913
# 30 -2.669126  4.379677  1.352901 -0.891371  0.462550 -0.015859
# 31  2.420593  0.233640  0.411765  0.227126  0.326926 -0.331524

# %%
# Plot Explained Variance vs Dimensions curve
